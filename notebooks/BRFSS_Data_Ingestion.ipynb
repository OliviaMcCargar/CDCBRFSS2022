# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import sys
import os

current = os.path.abspath('')
parent = os.path.dirname(current)
sys.path.append(parent)

from CDCBRFSS import *
from CDCBRFSS.data import *

# %%
display(HTML("<h3>Variable Descriptions</h3>"))
display(variable_descriptions)
# Out:
# <h3>Variable Descriptions</h3>
#      Variable                                        Description  \
# 0      _STATE                                    State FIPS Code
# 1      FMONTH                                         File Month
# 2       IDATE                                     Interview Date
# 3      IMONTH                                    Interview Month
# 4        IDAY                                      Interview Day
# ..        ...                                                ...
# 319  _DRNKWK2  Calculated total number of alcoholic beverages...
# 320  _RFDRHV8  Heavy drinkers (adult men having more than 14 ...
# 321  _FLSHOT7  Adults aged 65+ who have had a flu shot within...
# 322  _PNEUMO3  Adults aged 65+ who have ever had a pneumonia ...
# 323  _AIDTST4           Adults who have ever been tested for HIV
#
#                                                  Label  Type  \
# 0                                      State FIPS Code   Num
# 1                                           File Month   Num
# 2                                       Interview Date  Char
# 3                                      Interview Month  Char
# 4                                        Interview Day  Char
# ..                                                 ...   ...
# 319  Computed number of drinks of alcohol beverages...   Num
# 320     Heavy Alcohol Consumption  Calculated Variable   Num
# 321                       Flu Shot Calculated Variable   Num
# 322          Pneumonia Vaccination Calculated Variable   Num
# 323       Ever been tested for HIV calculated variable   Num
#
#                    Section Prologue
# 0    Record Identification
# 1    Record Identification
# 2    Record Identification
# 3    Record Identification
# 4    Record Identification
# ..                     ...      ...
# 319   Calculated Variables
# 320   Calculated Variables
# 321   Calculated Variables
# 322   Calculated Variables
# 323   Calculated Variables
#
# [324 rows x 6 columns]

# %%
display(HTML("<h3>Translation Table</h3>"))
display(translation_table)

# %%
display(HTML("<h3>BRFSS Survey Results 2022</h3>"))
display(raw_data_2022)
# Out:
# <h3>BRFSS Survey Results 2022</h3>
#         _STATE  FMONTH     IDATE IMONTH IDAY IYEAR  DISPCODE       SEQNO  \
# 0          1.0     1.0  02032022     02   03  2022    1100.0  2022000001
# 1          1.0     1.0  02042022     02   04  2022    1100.0  2022000002
# 2          1.0     1.0  02022022     02   02  2022    1100.0  2022000003
# 3          1.0     1.0  02032022     02   03  2022    1100.0  2022000004
# 4          1.0     1.0  02022022     02   02  2022    1100.0  2022000005
# ...        ...     ...       ...    ...  ...   ...       ...         ...
# 445127    78.0    11.0  12192022     12   19  2022    1100.0  2022001527
# 445128    78.0    11.0  12212022     12   21  2022    1100.0  2022001528
# 445129    78.0    11.0  11292022     11   29  2022    1100.0  2022001529
# 445130    78.0    11.0  12082022     12   08  2022    1100.0  2022001530
# 445131    78.0    11.0  12142022     12   14  2022    1100.0  2022001531
#
#                 _PSU  CTELENM1  ...  _SMOKGRP  _LCSREC  DRNKANY6  \
# 0       2.022000e+09       1.0  ...       4.0      NaN       2.0
# 1       2.022000e+09       1.0  ...       4.0      NaN       2.0
# 2       2.022000e+09       1.0  ...       4.0      NaN       2.0
# 3       2.022000e+09       1.0  ...       3.0      2.0       2.0
# 4       2.022000e+09       1.0  ...       4.0      NaN       1.0
# ...              ...       ...  ...       ...      ...       ...
# 445127  2.022002e+09       NaN  ...       4.0      NaN       7.0
# 445128  2.022002e+09       NaN  ...       4.0      NaN       2.0
# 445129  2.022002e+09       NaN  ...       1.0      NaN       7.0
# 445130  2.022002e+09       NaN  ...       4.0      NaN       2.0
# 445131  2.022002e+09       NaN  ...       3.0      NaN       1.0
#
#             DROCDY4_  _RFBING6      _DRNKWK2  _RFDRHV8  _FLSHOT7  _PNEUMO3  \
# 0       5.397605e-79       1.0  5.397605e-79       1.0       1.0       2.0
# 1       5.397605e-79       1.0  5.397605e-79       1.0       2.0       2.0
# 2       5.397605e-79       1.0  5.397605e-79       1.0       NaN       NaN
# 3       5.397605e-79       1.0  5.397605e-79       1.0       9.0       9.0
# 4       1.000000e+01       1.0  1.400000e+02       1.0       NaN       NaN
# ...              ...       ...           ...       ...       ...       ...
# 445127  9.000000e+02       9.0  9.990000e+04       9.0       NaN       NaN
# 445128  5.397605e-79       1.0  5.397605e-79       1.0       NaN       NaN
# 445129  9.000000e+02       9.0  9.990000e+04       9.0       2.0       2.0
# 445130  5.397605e-79       1.0  5.397605e-79       1.0       1.0       1.0
# 445131  5.000000e+01       2.0  9.990000e+04       9.0       NaN       NaN
#
#         _AIDTST4
# 0            2.0
# 1            2.0
# 2            2.0
# 3            2.0
# 4            2.0
# ...          ...
# 445127       1.0
# 445128       1.0
# 445129       2.0
# 445130       1.0
# 445131       2.0
#
# [445132 rows x 328 columns]
